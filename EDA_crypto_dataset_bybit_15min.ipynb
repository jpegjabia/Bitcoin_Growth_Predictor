# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_clean = pd.read_csv('crypto_dataset_bybit_15min_cleaned.csv', parse_dates=[0], index_col=0)
df_clean.head()
# Out:
#                      price_open  price_high  price_low  price_close  \
# datetime
# 2024-01-01 03:45:00     42350.6     42410.4    42290.5      42384.1
# 2024-01-01 04:00:00     42384.0     42426.4    42321.5      42337.3
# 2024-01-01 04:15:00     42337.2     42371.7    42250.5      42355.0
# 2024-01-01 04:30:00     42354.9     42395.2    42329.2      42359.0
# 2024-01-01 04:45:00     42361.8     42448.0    42350.1      42446.3
#
#                        volume_btc  bb_upper_abs  bb_middle_abs  bb_lower_abs  \
# datetime
# 2024-01-01 03:45:00  3.037507e+07  42773.243263      42489.155  42205.066737
# 2024-01-01 04:00:00  1.690058e+07  42767.483449      42492.365  42217.246551
# 2024-01-01 04:15:00  3.297172e+07  42752.061717      42499.045  42246.028283
# 2024-01-01 04:30:00  1.012458e+07  42744.523740      42502.735  42260.946260
# 2024-01-01 04:45:00  1.625623e+07  42737.526997      42508.810  42280.093003
#
#                      macd_line_abs  macd_signal_abs  ...  \
# ...

# %% [markdown]
# # EDA

# %%
print(f'Shape of the data: {df_clean.shape}')
print(f'Basic statistics: \n{df_clean.describe().T}')
# Out:
# Shape of the data: (58673, 32)
# Basic statistics:
#                               count          mean           std           min  \
# price_open                  58673.0  7.995390e+04  2.183051e+04  3.869210e+04
# price_high                  58673.0  8.008988e+04  2.185011e+04  3.881600e+04
# price_low                   58673.0  7.981452e+04  2.181144e+04  3.853150e+04
# price_close                 58673.0  7.995506e+04  2.183033e+04  3.869200e+04
# volume_btc                  58673.0  8.938092e+07  1.206612e+08  0.000000e+00
# bb_upper_abs                58673.0  8.053242e+04  2.192677e+04  3.910961e+04
# bb_middle_abs               58673.0  7.994401e+04  2.182876e+04  3.888947e+04
# bb_lower_abs                58673.0  7.935560e+04  2.174172e+04  3.845516e+04
# macd_line_abs               58673.0  8.160186e+00  2.308311e+02 -1.556164e+03
# macd_signal_abs             58673.0  8.165730e+00  2.173686e+02 -1.367243e+03
# ...
